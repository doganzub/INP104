# %% [markdown]
# # **1. Python'a Giriş**

# %% [markdown]
# # **1.0 Neden Python?**
#
# Programlama öğrenmeye başlamadan önce, neden Python dilini öğrenmek istediğimizi anlamak önemlidir. Bu bölümde Python'ın dünya genelindeki konumunu, popülerliğini ve önemini inceleyeceğiz.
#
# > Detaylı bilgi için: [neden_python.md](./neden_python.md)
#
# ---
#
# ### Python Nedir?
#
# Python, **Guido Van Rossum** tarafından 1991 yılında yayımlanan, yüksek seviyeli, genel amaçlı bir programlama dilidir. Dilin ismi, "Monty Python's Flying Circus" adlı İngiliz komedi grubunun gösterisinden esinlenerek konulmuştur.
#
# ---
#
# ### Dünya Genelinde En Popüler Dil
#
# Python, 2024-2025 yıllarında **tüm popülerlik endekslerinde 1. sırada** yer almaktadır:
#
# | Endeks | Python Sıralaması | Pazar Payı |
# |--------|-------------------|------------|
# | TIOBE 2024 | **1. sıra** | %23.84 |
# | PYPL 2024 | **1. sıra** | %29.71 |
# | GitHub 2024 | **1. sıra** | - |
# | Stack Overflow 2025 | **1. sıra** | %57.9 |
#
# **Dikkat Çekici İstatistikler:**
# - 2024'te TIOBE "Yılın Programlama Dili" seçildi
# - GitHub'da tarihinde ilk kez JavaScript'i geçti
# - Geliştiricilerin %86'sının birincil programlama dili
#
# ---
#
# ### Dünya Devleri Python Kullanıyor
#
# | Şirket | Python Kullanım Alanları |
# |--------|-------------------------|
# | **Google** | Arama motorları, TensorFlow, YouTube |
# | **Netflix** | Öneri algoritmaları, CDN yönetimi |
# | **Spotify** | Backend'in %80'i, müzik önerileri |
# | **Meta** | Facebook, Instagram, içerik önerileri |
# | **Dropbox** | Tüm altyapı (kurucusu Python yaratıcısı) |
#
# ---
#
# ### Yapay Zeka ve Veri Biliminin Dili
#
# Python, yapay zeka ve veri bilimi alanlarının **vazgeçilmez dili** haline gelmiştir:
#
# | Alan | Popüler Python Kütüphaneleri |
# |------|------------------------------|
# | Veri İşleme | Pandas, NumPy |
# | Makine Öğrenmesi | Scikit-learn |
# | Derin Öğrenme | TensorFlow, PyTorch |
# | Generative AI | Transformers, LangChain |
#
# - 2024'te Jupyter Notebook kullanımında **%92 artış**
# - Generative AI projelerinde **%98 artış**
# - Kaggle yarışmalarının **%90+'ında** Python
#
# ---
#
# ### Neden Yeni Başlayanlar İçin İdeal?
#
# 1. **Kolay Öğrenme**: Söz dizimi İngilizce'ye çok yakın
# 2. **Anında Geri Bildirim**: Derleme gerektirmez
# 3. **Geniş Kullanım Alanı**: Web, veri, AI, otomasyon
# 4. **Güçlü Topluluk**: Zengin kaynaklar ve destek
# 5. **İş Fırsatları**: Yüksek talep ve maaş imkanı
#
# ---
#
# ### Python Nasıl Telaffuz Edilir?
#
# - **İngilizce**: /ˈpaɪθɑːn/ → **[paytın]**
# - **Türkçeleştirilmiş**: **[piton]**
#
# Her iki kullanım da yaygındır ve kabul edilebilir.

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # **1.1 print() Fonksiyonu**
#
# `print()` fonksiyonu, Python'da ekrana çıktı vermemizi sağlayan temel fonksiyondur. Etkileşimli kabukta doğrudan yazdığımız ifadeler ekranda görünse de, Python programlarımızı bir dosyaya kaydedip çalıştırdığımızda, başında `print()` olmayan ifadeler çıktıda görünmez.
#
# Bu fonksiyon, tıpkı `type()` ve `len()` gibi Python'ın gömülü (built-in) fonksiyonlarından biridir. Fonksiyonların parantezleri içinde belirtilen öğelere **parametre** adı verilir.
#
# ---
#
# ### print() Fonksiyonunun Temel Kullanımı
#
# `print()` fonksiyonu bir veya birden fazla parametre alabilir. Birden fazla parametre verildiğinde, bunlar varsayılan olarak aralarına birer boşluk karakteri yerleştirilerek birleştirilir.

# %%
# print() fonksiyonu ile ekrana metin yazdırma
# Fonksiyon, parantez içindeki karakter dizisini ekrana basar
print("Merhaba Dünya!")  # En basit kullanım: tek parametre ile

# %%
# print() fonksiyonu birden fazla parametre alabilir
# Parametreler virgül ile ayrılır ve aralarına otomatik olarak boşluk eklenir
print("Python", "Programlama", "Dersi")  # Üç ayrı parametre, boşlukla birleştirilir

# %%
# Değişken kullanarak print() ile yazdırma
# Önce değer bir değişkene atanır, sonra değişken print() ile yazdırılır
dil = "Python programlama dili"  # Karakter dizisini değişkene atama
print(dil)  # Değişkenin değerini ekrana yazdırma

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # **1.2 Tırnak Kullanımı**
#
# Python'da karakter dizisi (string) tanımlamak için üç farklı tırnak seçeneği sunulur:
#
# 1. **Tek tırnak** (`' '`)
# 2. **Çift tırnak** (`" "`)
# 3. **Üç tırnak** (`""" """` veya `''' '''`)
#
# Bu üç tırnak tipinin çıktıları arasında hiçbir fark yoktur. Peki neden üç farklı tırnak çeşidi vardır?
#
# ---
#
# ### Tırnak Seçiminin Önemi
#
# Karakter dizisi içinde kesme işareti veya tırnak işareti geçtiğinde, Python'ın karakter dizisini başlatan ve bitiren tırnakları ayırt edebilmesi için farklı tırnak tipleri kullanılır. Python, karakter dizisini hangi tırnakla başlatmışsak, o tırnakla bitirmemizi bekler.

# %%
# Tek tırnak kullanımı
# Basit karakter dizileri için tek tırnak yeterlidir
print('Merhaba Python')  # Tek tırnak ile karakter dizisi tanımlama

# %%
# Çift tırnak içinde tek tırnak (kesme işareti) kullanımı
# Karakter dizisi içinde kesme işareti varsa, dışta çift tırnak kullanılır
# Böylece Python hangi tırnağın karakter dizisini başlatıp bitirdiğini ayırt edebilir
print("İstanbul'un 5 günlük hava durumu tahmini")  # Kesme işareti problem yaratmaz

# %%
# Tek tırnak içinde çift tırnak kullanımı
# Karakter dizisi içinde çift tırnak varsa, dışta tek tırnak kullanılır
# Bu sayede iç içe tırnak işaretleri birbirine karışmaz
print('Python programlama dilinin adı "piton" yılanından gelmez')  # İç tırnak sorunsuz

# %%
# Üç tırnak kullanımı - Çok satırlı metin için idealdir
# Üç tırnak, Enter tuşuna basıldığında hata vermez ve satır atlamaya izin verir
# Genellikle birden fazla satıra yayılmış metinlerde tercih edilir
print("""Bu bir
çok satırlı
metin örneğidir.""")  # Her satır olduğu gibi yazdırılır

# %%
# Üç tırnak ile karmaşık metin örneği
# Hem tek tırnak hem çift tırnak içeren metinler için üç tırnak kullanılabilir
print("""Python programlama dili Guido Van Rossum
adlı Hollandalı bir programcı tarafından 90'lı
yılların başında geliştirilmeye başlanmıştır. Çoğu
insan, isminin "Python" olmasına bakarak, bu programlama
dilinin, adını piton yılanından aldığını düşünür.
Ancak zannedildiğinin aksine bu programlama dilinin
adı piton yılanından gelmez.""")  # Hem kesme hem çift tırnak kullanılabilir

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # **1.3 Veri Tipleri**
#
# Python'da her değerin bir **veri tipi** vardır. Programlama sürecinde verilerle çalışırken, bu verilerin hangi tipte olduğunu bilmek son derece önemlidir. Çünkü farklı veri tipleri üzerinde farklı işlemler yapılabilir.
#
# ---
#
# ### Temel Veri Tipleri
#
# Python'da en sık kullanılan temel veri tipleri şunlardır:
#
# | Veri Tipi | Python Kodu | Açıklama |
# |-----------|-------------|----------|
# | **Karakter Dizisi** | `str` | Metin verileri (harfler, kelimeler, cümleler) |
# | **Tam Sayı** | `int` | Ondalık kısmı olmayan sayılar |
# | **Ondalıklı Sayı** | `float` | Ondalık kısmı olan sayılar |
#
# ---
#
# ### Karakter Dizisi (String - str)
#
# Karakter dizileri, tırnak içinde yazılan her türlü metni ifade eder. Harfler, rakamlar, boşluklar ve özel karakterler içerebilir.

# %%
# String (Karakter Dizisi) veri tipi
# Tırnak içinde yazılan her değer karakter dizisidir
# Harfler, rakamlar, boşluklar ve özel karakterler içerebilir
isim = "Züber Doğan"  # Karakter dizisi değişkene atanıyor
print(isim)  # Değişkenin değerini yazdırır: Züber Doğan
print(type(isim))  # Veri tipini gösterir: <class 'str'>

# %% [markdown]
# ### Tam Sayı (Integer - int)
#
# Tam sayılar, ondalık kısmı olmayan pozitif veya negatif sayılardır. Python'da tam sayıların boyutu konusunda pratik bir sınır yoktur.

# %%
# Integer (Tam Sayı) veri tipi
# Ondalık kısmı olmayan sayılar integer olarak kabul edilir
# Negatif veya pozitif olabilir, boyut sınırı pratik olarak yoktur
yil = 1978  # Tam sayı değişkene atanıyor
print(yil)  # Değerini yazdırır: 1978
print(type(yil))  # Veri tipini gösterir: <class 'int'>

# %% [markdown]
# ### Ondalıklı Sayı (Float)
#
# Ondalıklı sayılar, kesirli değerleri temsil eder. Python'da ondalık ayırıcı olarak nokta (`.`) kullanılır, virgül değil.

# %%
# Float (Ondalıklı Sayı) veri tipi
# Nokta ile ayrılmış ondalık sayılar float olarak kabul edilir
# Python'da ondalık ayırıcı nokta (.) kullanılır, virgül değil
kilo = 73.3  # Ondalıklı sayı değişkene atanıyor
print(kilo)  # Değerini yazdırır: 73.3
print(type(kilo))  # Veri tipini gösterir: <class 'float'>

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # **1.4 type() ve len() Fonksiyonları**
#
# Python'da gömülü (built-in) fonksiyonlar, herhangi bir kütüphane içe aktarmadan doğrudan kullanabileceğimiz hazır fonksiyonlardır.
#
# ---
#
# ### type() Fonksiyonu
#
# `type()` fonksiyonu, kendisine verilen değerin veya değişkenin **veri tipini** döndürür. Bu fonksiyon, özellikle hata ayıklama (debugging) sürecinde ve veri tiplerini kontrol etmek istediğimizde çok faydalıdır.
#
# ---
#
# ### len() Fonksiyonu
#
# `len()` fonksiyonu, karakter dizilerinin **uzunluğunu** (karakter sayısını) döndürür. Ayrıca listeler, demetler ve sözlükler gibi veri yapılarının eleman sayısını öğrenmek için de kullanılır.

# %%
# type() fonksiyonu - Veri tipini belirler ve döndürür
# Herhangi bir değerin hangi tipte olduğunu öğrenmek için kullanılır
# Hata ayıklama sürecinde çok faydalıdır
print(type("Merhaba"))  # str - Karakter dizisi (tırnak içinde olduğu için)
print(type(42))         # int - Tam sayı (ondalık kısmı yok)
print(type(3.14))       # float - Ondalıklı sayı (nokta ile ayrılmış)

# %%
# len() fonksiyonu - Karakter dizisinin uzunluğunu (karakter sayısını) verir
# Boşluklar ve özel karakterler de sayılır
# Yalnızca karakter dizileri ve dizilere (list, tuple) uygulanabilir
metin = "firat_ozgul_1980"  # 16 karakterlik bir karakter dizisi
print(len(metin))  # 16 - Boşluk ve alt çizgi dahil tüm karakterler sayılır

# %%
# Sayıların basamak sayısını bulmak için len() kullanımı
# Dikkat: len() doğrudan sayılara uygulanamaz
# Önce sayı str() ile karakter dizisine çevrilmeli, sonra len() uygulanmalı
sayi = 12343423432  # Bir tam sayı
print(len(str(sayi)))  # 11 - Sayı önce string'e çevrildi, sonra uzunluğu hesaplandı

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # **1.5 print() Fonksiyonunun Özel Parametreleri**
#
# `print()` fonksiyonu son derece güçlü bir araçtır ve davranışını özelleştirmemizi sağlayan **isimli parametreler** içerir. Bu parametreler, fonksiyonda görünmese bile her zaman oradadır ve varsayılan değerlere sahiptir.
#
# ---
#
# ### sep Parametresi (Separator - Ayırıcı)
#
# `sep` parametresi, `print()` fonksiyonuna verilen parametrelerin arasına hangi karakterin yerleştirileceğini belirler. Varsayılan değeri bir adet boşluk karakteridir (`" "`).
#
# ---
#
# ### end Parametresi
#
# `end` parametresi, `print()` fonksiyonunun çıktısının sonuna hangi karakterin ekleneceğini belirler. Varsayılan değeri yeni satır karakteridir (`"\n"`).

# %%
# sep parametresi - Parametreler arası ayırıcı karakteri belirler
# Varsayılan değeri bir boşluk karakteridir (" ")
# sep="istenilen_karakter" şeklinde özelleştirilebilir
print("Adana", "Mersin", sep="-")  # Çıktı: Adana-Mersin (boşluk yerine tire)

# %%
# sep parametresi ile yeni satır karakteri kullanımı
# \n özel karakteri yeni satır anlamına gelir
# Her parametre ayrı satırda yazdırılır
print("Adana", "Mersin", "İstanbul", sep="\n")  # Her şehir ayrı satırda

# %%
# sep parametresi ile URL birleştirme örneği
# sep="" (boş karakter dizisi) parametreler arasına hiçbir şey koymaz
# Varsayılan boşluk karakteri atlanarak parametreler birleştirilir
print("http://", "www.", "python.", "org", sep="")  # Çıktı: http://www.python.org

# %%
# end parametresi - Satır sonuna eklenecek karakteri belirler
# Varsayılan değeri yeni satır karakteridir (\n)
# end="istenilen_karakter" şeklinde özelleştirilebilir
print("Bugün günlerden Salı", end=".\n")  # Satır sonuna nokta ve yeni satır eklenir

# %%
# end parametresi ile aynı satırda yazdırma
# end="" kullanıldığında bir sonraki print aynı satırda devam eder
print("Python ", end="")  # Satır sonu yok, bir sonraki çıktı aynı satırda
print("Programlama")  # Bu çıktı yukarıdakinin devamı olarak görünür

# %%
# sep ve end parametrelerini birlikte kullanma
# Her iki parametre de aynı print() içinde kullanılabilir
# sep parametrelerin arasına, end ise en sona karakter ekler
print("T", "C", sep=".", end="\n\n")  # Çıktı: T.C ve iki satır boşluk

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # **1.6 Kaçış Dizileri (Escape Sequences)**
#
# Kaçış dizileri, karakter dizileri içinde özel anlam taşıyan karakter kombinasyonlarıdır. Ters eğik çizgi (`\`) ile başlarlar ve normal yollarla yazılamayan karakterleri temsil ederler.
#
# | Kaçış Dizisi | Anlamı |
# |--------------|--------|
# | `\n` | Yeni satır (newline) |
# | `\t` | Sekme (tab) |
# | `\\` | Ters eğik çizgi |
# | `\'` | Tek tırnak |
# | `\"` | Çift tırnak |

# %%
# \n kaçış dizisi - Yeni satır karakteri
# Karakter dizisini bulunduğu noktadan böler ve geri kalanı alt satıra geçirir
print("Birinci satır\nİkinci satır\nÜçüncü satır")  # Her \n'de alt satıra geçer

# %%
# \t kaçış dizisi - Sekme (tab) karakteri
# Metinde belirli bir boşluk bırakır, hizalama için kullanışlıdır
print("İsim\tYaş\tŞehir")  # Sütunlar arasında tab boşluğu
print("Ali\t25\tAnkara")  # Veriler hizalı görünür

# %%
# \' ve \" kaçış dizileri - Tırnak karakterlerini yazdırma
# Aynı tip tırnak içinde tırnak karakteri kullanmak gerektiğinde
print('İstanbul\'un tarihi')  # Tek tırnak içinde kesme işareti
print("\"Python\" bir programlama dilidir")  # Çift tırnak içinde çift tırnak

# %% [markdown]
# ---
#
# ## **Özet**
#
# Bu derste öğrenilen konular:
#
# 1. **Neden Python?**: Python'ın dünya genelindeki popülerliği ve önemi
# 2. **print() Fonksiyonu**: Ekrana çıktı vermek için kullanılan temel fonksiyon
# 3. **Tırnak Kullanımı**: Tek, çift ve üç tırnak arasındaki farklar ve kullanım alanları
# 4. **Veri Tipleri**: `str` (karakter dizisi), `int` (tam sayı), `float` (ondalıklı sayı)
# 5. **type() Fonksiyonu**: Veri tipini belirlemek için kullanılır
# 6. **len() Fonksiyonu**: Karakter dizisinin uzunluğunu hesaplar
# 7. **sep Parametresi**: Parametreler arası ayırıcı karakteri belirler
# 8. **end Parametresi**: Satır sonuna eklenecek karakteri belirler
# 9. **Kaçış Dizileri**: `\n`, `\t`, `\'`, `\"` gibi özel karakterler
#
# ---
#
# > **Ek Kaynak:** Detaylı Python popülerlik araştırması için [neden_python.md](./neden_python.md) dosyasını inceleyebilirsiniz.

# %%
# ============================================================================
# ALIŞTIRMA GÖREVLERİ – Python'a Giriş
# ============================================================================
# Aşağıdaki görevleri verilen yönergelere göre tamamlayınız.
# Her bölüm, derste anlatılan konuların benzeri alıştırmalardan oluşmaktadır.
# ??? işaretlerinin yerine doğru kodları yazınız.
# ============================================================================




# ============================================================================
# 🟩 GÖREV 1: print() fonksiyonu – Temel kullanım
# ============================================================================
# print() fonksiyonunu kullanarak ekrana "Merhaba Python!" yazdırın.
#
# İpucu: print("Merhaba Dünya!") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(???)




# ============================================================================
# 🟩 GÖREV 2: print() fonksiyonu – Birden fazla parametre
# ============================================================================
# print() fonksiyonuna üç ayrı parametre vererek
# "Veri", "Bilimi", "Temelleri" ifadelerini yazdırın.
#
# İpucu: print("Python", "Programlama", "Dersi") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(???, ???, ???)




# ============================================================================
# 🟩 GÖREV 3: Değişken ile print() kullanımı
# ============================================================================
# "Yapay zeka ve veri bilimi" ifadesini bir değişkene atayın
# ve bu değişkeni print() ile yazdırın.
#
# İpucu: dil = "Python programlama dili" ve print(dil) örneğindeki gibi yapınız.
# ------------------------------------------------------------

# konu = ???
# print(???)




# ============================================================================
# 🟩 GÖREV 4: Tek tırnak kullanımı
# ============================================================================
# Tek tırnak kullanarak "Merhaba Dünya" ifadesini yazdırın.
#
# İpucu: print('Merhaba Python') örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(???)




# ============================================================================
# 🟩 GÖREV 5: Çift tırnak içinde kesme işareti kullanımı
# ============================================================================
# Çift tırnak kullanarak aşağıdaki metni yazdırın:
# Ankara'nın başkent oluşu 1923'tür
# (Karakter dizisi içinde kesme işareti olduğuna dikkat edin!)
#
# İpucu: print("İstanbul'un 5 günlük hava durumu tahmini") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(???)




# ============================================================================
# 🟩 GÖREV 6: Tek tırnak içinde çift tırnak kullanımı
# ============================================================================
# Tek tırnak kullanarak aşağıdaki metni yazdırın:
# Öğretmen "Sınav iptal" dedi
#
# İpucu: print('Python... "piton" yılanından gelmez') örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(???)




# ============================================================================
# 🟩 GÖREV 7: Üç tırnak – Çok satırlı metin
# ============================================================================
# Üç tırnak (""") kullanarak aşağıdaki çok satırlı metni yazdırın:
# Python öğreniyorum.
# Bu çok eğlenceli.
# Devam edeceğim.
#
# İpucu: print("""Bu bir
# çok satırlı
# metin örneğidir.""") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(???)




# ============================================================================
# 🟩 GÖREV 8: String (Karakter Dizisi) veri tipi
# ============================================================================
# Bir değişken oluşturun ve kendi şehrinizin adını atayın.
# Ardından değişkenin değerini ve veri tipini yazdırın.
#
# İpucu: isim = "Züber Doğan" örneğindeki gibi yapınız.
# ------------------------------------------------------------

# sehir = ???
# print(???)
# print(type(???))




# ============================================================================
# 🟩 GÖREV 9: Integer (Tam Sayı) veri tipi
# ============================================================================
# Bir değişken oluşturun ve doğum yılınızı atayın.
# Ardından değişkenin değerini ve veri tipini yazdırın.
#
# İpucu: yil = 1978 örneğindeki gibi yapınız.
# ------------------------------------------------------------

# dogum_yili = ???
# print(???)
# print(type(???))




# ============================================================================
# 🟩 GÖREV 10: Float (Ondalıklı Sayı) veri tipi
# ============================================================================
# Bir değişken oluşturun ve boyunuzu metre cinsinden (örn: 1.68) atayın.
# Ardından değişkenin değerini ve veri tipini yazdırın.
#
# İpucu: kilo = 73.3 örneğindeki gibi yapınız.
# ------------------------------------------------------------

# boy = ???
# print(???)
# print(type(???))




# ============================================================================
# 🟩 GÖREV 11: type() fonksiyonu
# ============================================================================
# Aşağıdaki değerlerin veri tiplerini type() ile yazdırın:
# "Ankara", 2025, 98.6
#
# İpucu: print(type("Merhaba")) örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(type(???))
# print(type(???))
# print(type(???))




# ============================================================================
# 🟩 GÖREV 12: len() fonksiyonu – Karakter dizisi uzunluğu
# ============================================================================
# "ahmet_yilmaz_1995" karakter dizisinin uzunluğunu bulun ve yazdırın.
#
# İpucu: metin = "firat_ozgul_1980" ve print(len(metin)) örneğindeki gibi yapınız.
# ------------------------------------------------------------

# metin = ???
# print(len(???))




# ============================================================================
# 🟩 GÖREV 13: len() fonksiyonu – Sayının basamak sayısı
# ============================================================================
# 9876543210 sayısının basamak sayısını len() kullanarak bulun.
# Dikkat: len() doğrudan sayılara uygulanamaz, önce str() ile çevirmelisiniz.
#
# İpucu: sayi = 12343423432 ve print(len(str(sayi))) örneğindeki gibi yapınız.
# ------------------------------------------------------------

# sayi = ???
# print(len(str(???)))




# ============================================================================
# 🟩 GÖREV 14: sep parametresi – Ayırıcı karakter
# ============================================================================
# "Elma", "Armut", "Çilek" değerlerini aralarına " | " koyarak yazdırın.
#
# İpucu: print("Adana", "Mersin", sep="-") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print("Elma", "Armut", "Çilek", sep=???)




# ============================================================================
# 🟩 GÖREV 15: sep parametresi – Yeni satır ile ayırma
# ============================================================================
# "Pazartesi", "Salı", "Çarşamba" değerlerini her birini ayrı satırda yazdırın.
#
# İpucu: print("Adana", "Mersin", "İstanbul", sep="\n") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print("Pazartesi", "Salı", "Çarşamba", sep=???)




# ============================================================================
# 🟩 GÖREV 16: sep parametresi – Boş ayırıcı ile birleştirme
# ============================================================================
# sep="" kullanarak "https://", "www.", "google.", "com" parçalarını
# aralarında hiçbir boşluk olmadan birleştirerek yazdırın.
#
# İpucu: print("http://", "www.", "python.", "org", sep="") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print("https://", "www.", "google.", "com", sep=???)




# ============================================================================
# 🟩 GÖREV 17: end parametresi – Satır sonu karakteri
# ============================================================================
# "Merhaba Dünya" yazdırın ve satır sonuna "!" ekleyin, ardından yeni satıra geçin.
#
# İpucu: print("Bugün günlerden Salı", end=".\n") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print("Merhaba Dünya", end=???)




# ============================================================================
# 🟩 GÖREV 18: end parametresi – Aynı satırda yazdırma
# ============================================================================
# İki ayrı print() kullanarak "Veri " ve "Bilimi" ifadelerini aynı satırda yazdırın.
#
# İpucu: print("Python ", end="") ve print("Programlama") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print("Veri ", end=???)
# print("Bilimi")




# ============================================================================
# 🟩 GÖREV 19: sep ve end parametrelerini birlikte kullanma
# ============================================================================
# "A", "B", "C" değerlerini aralarına " - " koyarak yazdırın
# ve satır sonuna " >>> SON" ekleyin.
#
# İpucu: print("T", "C", sep=".", end="\n\n") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print("A", "B", "C", sep=???, end=???)




# ============================================================================
# 🟩 GÖREV 20: \n kaçış dizisi – Yeni satır
# ============================================================================
# Tek bir print() ile aşağıdaki çıktıyı elde edin:
# Satır 1
# Satır 2
# Satır 3
#
# İpucu: print("Birinci satır\nİkinci satır\nÜçüncü satır") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(???)




# ============================================================================
# 🟩 GÖREV 21: \t kaçış dizisi – Sekme (tab) karakteri
# ============================================================================
# Tek bir print() ile aşağıdaki hizalı tablo çıktısını elde edin:
# Ürün    Fiyat   Adet
# Kalem   5       100
#
# İpucu: print("İsim\tYaş\tŞehir") ve print("Ali\t25\tAnkara") örneğindeki gibi yapınız.
# ------------------------------------------------------------

# print(???)
# print(???)




# ============================================================================
# 🟩 GÖREV 22: \' ve \" kaçış dizileri – Tırnak karakterleri
# ============================================================================
# Aşağıdaki çıktıları elde edin:
# Ankara'nın kalesi
# "Merhaba" dedi ve gitti
#
# İpucu: print('İstanbul\'un tarihi') ve print("\"Python\" bir programlama dilidir") örneklerindeki gibi yapınız.
# ------------------------------------------------------------

# print(???)
# print(???)

# %%
# ============================================================================
# 🟨 CEVAP ANAHTARI – Python'a Giriş
# ============================================================================
# Yukarıdaki görevlerin tamamlanmış çözümleri aşağıda verilmiştir.
# ============================================================================




# ============================================================================
# 🟨 CEVAP 1: print() fonksiyonu – Temel kullanım
# ============================================================================
print("Merhaba Python!")  # Ekrana metin yazdırır

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 2: print() fonksiyonu – Birden fazla parametre
# ============================================================================
print("Veri", "Bilimi", "Temelleri")  # Üç parametre, araya otomatik boşluk eklenir

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 3: Değişken ile print() kullanımı
# ============================================================================
konu = "Yapay zeka ve veri bilimi"  # Karakter dizisini değişkene atama
print(konu)  # Değişkenin değerini yazdırır

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 4: Tek tırnak kullanımı
# ============================================================================
print('Merhaba Dünya')  # Tek tırnak ile karakter dizisi tanımlama

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 5: Çift tırnak içinde kesme işareti kullanımı
# ============================================================================
print("Ankara'nın başkent oluşu 1923'tür")  # Çift tırnak içinde kesme işareti sorunsuz

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 6: Tek tırnak içinde çift tırnak kullanımı
# ============================================================================
print('Öğretmen "Sınav iptal" dedi')  # Tek tırnak içinde çift tırnak sorunsuz

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 7: Üç tırnak – Çok satırlı metin
# ============================================================================
print("""Python öğreniyorum.
Bu çok eğlenceli.
Devam edeceğim.""")  # Üç tırnak ile çok satırlı metin

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 8: String (Karakter Dizisi) veri tipi
# ============================================================================
sehir = "Adana"  # Karakter dizisi değişkene atanıyor
print(sehir)  # Değişkenin değerini yazdırır: Adana
print(type(sehir))  # Veri tipini gösterir: <class 'str'>

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 9: Integer (Tam Sayı) veri tipi
# ============================================================================
dogum_yili = 2003  # Tam sayı değişkene atanıyor
print(dogum_yili)  # Değerini yazdırır: 2003
print(type(dogum_yili))  # Veri tipini gösterir: <class 'int'>

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 10: Float (Ondalıklı Sayı) veri tipi
# ============================================================================
boy = 1.68  # Ondalıklı sayı değişkene atanıyor
print(boy)  # Değerini yazdırır: 1.68
print(type(boy))  # Veri tipini gösterir: <class 'float'>

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 11: type() fonksiyonu
# ============================================================================
print(type("Ankara"))  # str - Karakter dizisi (tırnak içinde olduğu için)
print(type(2025))      # int - Tam sayı (ondalık kısmı yok)
print(type(98.6))      # float - Ondalıklı sayı (nokta ile ayrılmış)

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 12: len() fonksiyonu – Karakter dizisi uzunluğu
# ============================================================================
metin = "ahmet_yilmaz_1995"  # 17 karakterlik bir karakter dizisi
print(len(metin))  # 17 - Alt çizgi dahil tüm karakterler sayılır

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 13: len() fonksiyonu – Sayının basamak sayısı
# ============================================================================
sayi = 9876543210  # Bir tam sayı
print(len(str(sayi)))  # 10 - Sayı önce string'e çevrildi, sonra uzunluğu hesaplandı

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 14: sep parametresi – Ayırıcı karakter
# ============================================================================
print("Elma", "Armut", "Çilek", sep=" | ")  # Çıktı: Elma | Armut | Çilek

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 15: sep parametresi – Yeni satır ile ayırma
# ============================================================================
print("Pazartesi", "Salı", "Çarşamba", sep="\n")  # Her gün ayrı satırda

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 16: sep parametresi – Boş ayırıcı ile birleştirme
# ============================================================================
print("https://", "www.", "google.", "com", sep="")  # Çıktı: https://www.google.com

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 17: end parametresi – Satır sonu karakteri
# ============================================================================
print("Merhaba Dünya", end="!\n")  # Satır sonuna ünlem ve yeni satır eklenir

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 18: end parametresi – Aynı satırda yazdırma
# ============================================================================
print("Veri ", end="")  # Satır sonu yok, bir sonraki çıktı aynı satırda
print("Bilimi")  # Bu çıktı yukarıdakinin devamı olarak görünür: Veri Bilimi

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 19: sep ve end parametrelerini birlikte kullanma
# ============================================================================
print("A", "B", "C", sep=" - ", end=" >>> SON\n")  # Çıktı: A - B - C >>> SON

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 20: \n kaçış dizisi – Yeni satır
# ============================================================================
print("Satır 1\nSatır 2\nSatır 3")  # Her \n'de alt satıra geçer

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 21: \t kaçış dizisi – Sekme (tab) karakteri
# ============================================================================
print("Ürün\tFiyat\tAdet")  # Sütunlar arasında tab boşluğu
print("Kalem\t5\t100")  # Veriler hizalı görünür

print(f"\n{'-'*82}\n")




# ============================================================================
# 🟨 CEVAP 22: \' ve \" kaçış dizileri – Tırnak karakterleri
# ============================================================================
print('Ankara\'nın kalesi')  # Tek tırnak içinde kesme işareti
print("\"Merhaba\" dedi ve gitti")  # Çift tırnak içinde çift tırnak
